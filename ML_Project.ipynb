# %% [markdown]
# <a href="https://colab.research.google.com/github/AnkitaLomte26/Buffer-6.0/blob/main/ML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Importing all the necessary Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Loading the Data to a Pandas data frame

# %%
credit_card_data = pd.read_csv("/content/drive/MyDrive/ML_PROJECT/Credit_Card_Dataset.zip")

# %% [markdown]
# Preview the first few rows of the dataset

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# Preview the last few rows of the dataset

# %%
credit_card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [5 rows x 31 columns]

# %%
print("Dataset Shape (Rows, Columns):",credit_card_data.shape)
# Out:
# Dataset Shape (Rows, Columns): (284807, 31)

# %%
print("\nDataset Information:\n")
print(credit_card_data.info())
# Out:
# Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB
# None

# %% [markdown]
# Data visulization

# %%
import matplotlib.pyplot as plt

# %%
legit = credit_card_data[credit_card_data.Class==0]
fraud = credit_card_data[credit_card_data.Class ==1]

# %%
plt.title("Fraud vs. Legit Transactions")
plt.xlabel("Time(duration)")
plt.ylabel("Amount")
plt.scatter(legit.Amount,legit.Time,label = "legal",color = 'Red',marker = "*")
plt.scatter(fraud.Amount,fraud.Time,label="fraud",color='black',marker="o")

plt.show()

# %% [markdown]
# Data cleaning

# %%
print("\nMissing Values in Each Column:\n")
print(credit_card_data.isnull().sum())
# Out:
# Missing Values in Each Column:
#
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Distribution of legit transctions and fraudulent transctions
print("\nClass Distribution:")
print(credit_card_data['Class'].value_counts())
# Out:
# Class Distribution:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# 0 --> Legal transaction 1 --> fraudulent transaction

# %% [markdown]
# Data modification

# %%
# Separting the data for Analysis
legit = credit_card_data[credit_card_data.Class==0]
fraud = credit_card_data[credit_card_data.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %% [markdown]
# Statistical Measure of data

# %%
print('Details of legit transaction')
legit.Amount.describe()
# Out:
# Details of legit transaction
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
print('Amount details of the fraudulent transaction')
fraud.Amount.describe()
# Out:
# Amount details of the fraudulent transaction
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# Compare the values for both transcations

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#Pandas dataframe.groupby() function is used to split the data
# into groups based on some criteria.

# %% [markdown]
# Under Sampling
# Build a sample dataset containing similar distribution of normal transactions and fraudulent transactions.
# Number of Fradulent -->492

# %%
legit_sample = legit.sample(n=492)

# %%
# Conactentaing the two dataframes
new_dataset = pd.concat([legit_sample,fraud] ,axis = 0)
# axis = 0 - means values are added row wise
# all 492 values are added below this legit sample
# axis = 1 - means values are added colum wise

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 125710   77768.0  1.152877  0.169913  0.563077  0.882640 -0.103844  0.270943
# 61612    49912.0 -0.402090  0.203785  1.901939  0.607834 -0.250422  0.621916
# 217608  140960.0 -0.958483  1.822915 -0.685850  0.565747  1.151778 -0.236519
# 193404  130122.0  1.941465 -0.119548 -1.882833  0.271226  0.551253 -0.291076
# 79873    58217.0  0.943324 -0.864723  0.921603 -0.678741 -1.274150 -0.023356
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 125710 -0.267858  0.143579 -0.110569  ...  0.237108  0.785645 -0.161719
# 61612  -0.116047  0.235368 -1.648287  ... -0.227083  0.059094 -0.085969
# 217608  1.289429 -0.970834  1.189425  ... -0.039640  0.976870 -0.461960
# 193404  0.094329 -0.026237  0.331765  ... -0.301238 -0.938427  0.256175
# 79873  -0.710645  0.285016  1.793062  ...  0.092271  0.314828 -0.078717
#
#              V24       V25       V26       V27       V28  Amount  Class
# 125710 -0.260542  0.593891 -0.208010  0.053678  0.012476    6.24      0
# 61612   0.022981 -0.194941 -0.200275  0.210919  0.136414   19.99      0
# 217608 -1.129755 -0.321006  0.158417 -0.817112 -0.658006    6.26      0
# 193404  0.113727 -0.300994  0.174414 -0.077441 -0.036210   54.99      0
# 79873   0.226147  0.336239 -0.689416  0.088144  0.038838  100.75      0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
#              V24       V25       V26       V27       V28  Amount  Class
# 279863 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00      1
# 280143 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76      1
# 280149  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89      1
# 281144 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00      1
# 281674 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53      1
#
# [5 rows x 31 columns]

# %% [markdown]
# Building the model

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94726.857724 -0.030078  0.123265 -0.012096 -0.109630 -0.138883
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.042422  0.055016 -0.058535  0.040890  ...  0.036884 -0.077086
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.026714 -0.008608  0.031721 -0.006561  0.011436  0.009552  0.009845
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       96.840996
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Spliting the data into features and targets

# %%
x = new_dataset.drop(columns = 'Class',axis = 1)

# %%
y = new_dataset['Class']

# %%
print(x)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 125710   77768.0  1.152877  0.169913  0.563077  0.882640 -0.103844  0.270943
# 61612    49912.0 -0.402090  0.203785  1.901939  0.607834 -0.250422  0.621916
# 217608  140960.0 -0.958483  1.822915 -0.685850  0.565747  1.151778 -0.236519
# 193404  130122.0  1.941465 -0.119548 -1.882833  0.271226  0.551253 -0.291076
# 79873    58217.0  0.943324 -0.864723  0.921603 -0.678741 -1.274150 -0.023356
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 125710 -0.267858  0.143579 -0.110569  ... -0.087796  0.237108  0.785645
# 61612  -0.116047  0.235368 -1.648287  ... -0.273607 -0.227083  0.059094
# 217608  1.289429 -0.970834  1.189425  ...  0.871105 -0.039640  0.976870
# 193404  0.094329 -0.026237  0.331765  ... -0.068570 -0.301238 -0.938427
# 79873  -0.710645  0.285016  1.793062  ... -0.005275  0.092271  0.314828
# ...          ...       ...       ...  ...       ...       ...       ...
# 279863 -0.882850  0.697211 -2.064945  ...  1.252967  0.778584 -0.319189
# 280143 -1.413170  0.248525 -1.127396  ...  0.226138  0.370612  0.028234
# 280149 -2.234739  1.210158 -0.652250  ...  0.247968  0.751826  0.834108
# 281144 -2.208002  1.058733 -1.632333  ...  0.306271  0.583276 -0.269209
# 281674  0.223050 -0.068384  0.577829  ... -0.017652 -0.164350 -0.295135
#
#              V23       V24       V25       V26       V27       V28  Amount
# 125710 -0.161719 -0.260542  0.593891 -0.208010  0.053678  0.012476    6.24
# 61612  -0.085969  0.022981 -0.194941 -0.200275  0.210919  0.136414   19.99
# 217608 -0.461960 -1.129755 -0.321006  0.158417 -0.817112 -0.658006    6.26
# 193404  0.256175  0.113727 -0.300994  0.174414 -0.077441 -0.036210   54.99
# 79873  -0.078717  0.226147  0.336239 -0.689416  0.088144  0.038838  100.75
# ...          ...       ...       ...       ...       ...       ...     ...
# 279863  0.639419 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00
# 280143 -0.145640 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76
# 280149  0.190944  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89
# 281144 -0.456108 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00
# 281674 -0.072173 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53
#
# [984 rows x 30 columns]

# %% [markdown]
# Split the data into training data and testing data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,stratify=y ,random_state=2)
#stratify=Y: strafied the data based on Y
#random_state=2 : means how you want to split your data

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
# Logistic Regression - For binary classification problem
print(x.shape,x_train.shape,x_test.shape)
#x.shape = actual dataset
# x_train and X_test====>> data splitted sample count print
# Out:
# (984, 30) (787, 30) (197, 30)

# %% [markdown]
# Model training
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
#Training the regression model with training data
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

#
#        [2.27865538e-04, 9.99772134e-01],
#        [7.55324797e-03, 9.92446752e-01],
#        [9.57024341e-01, 4.29756587e-02],
#        [2.91100477e-12, 1.00000000e+00],
#        [3.68569262e-03, 9.96314307e-01],
#        [6.72249710e-08, 9.99999933e-01],
#        [8.27888170e-01, 1.72111830e-01]])

# %% [markdown]
# Evaluating parameters

# %%
from sklearn import metrics

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test,y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.934010152284264
# Precision: 0.967032967032967
# Recall: 0.8979591836734694
# F1 Score: 0.9312169312169312

# %% [markdown]
# Confusion matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

x_test_prediction = model.predict(x_test)

conf_matrix = confusion_matrix(y_test, x_test_prediction)

disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=[False, True])
disp.plot(cmap=plt.cm.Blues)
plt.show()

# %%
print(conf_matrix)
# Out:
# [[96  3]
#  [10 88]]

# %% [markdown]
# Classification Report

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(x_test)

print("Classification Report on Testing Data:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report on Testing Data:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94        99
#            1       0.97      0.90      0.93        98
#
#     accuracy                           0.93       197
#    macro avg       0.94      0.93      0.93       197
# weighted avg       0.94      0.93      0.93       197

# %% [markdown]
# Random Forest
# Fit the model in RandomForest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rfc.predict(x_test)

# %%
from sklearn import metrics

print("Evaluation Metrics (Random Forest):")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# Evaluation Metrics (Random Forest):
# Accuracy: 0.934010152284264
# Precision: 0.967032967032967
# Recall: 0.8979591836734694
# F1 Score: 0.9312169312169312

# %% [markdown]
# Confusion matrix

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
print("Confusion Matrix (Random Forest):")
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Legit (0)", "Fraud (1)"])
disp.plot(cmap=plt.cm.Greens)
plt.title("Random Forest - Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix (Random Forest):

# %% [markdown]
# Classification Report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92        99
#            1       0.97      0.87      0.91        98
#
#     accuracy                           0.92       197
#    macro avg       0.92      0.92      0.92       197
# weighted avg       0.92      0.92      0.92       197

# %% [markdown]
#  Naive Bayes Model

# %%
from sklearn.naive_bayes import GaussianNB
nb_model = GaussianNB()

# %% [markdown]
# Train the model on training set

# %%
nb_model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %% [markdown]
# Make predictions on the testing

# %%
y_pred = nb_model.predict(x_test)

# %% [markdown]
# Evaluate Model Performance

# %%
from sklearn import metrics
print("Evaluation Metrics (Naive Bayes):")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# Evaluation Metrics (Naive Bayes):
# Accuracy: 0.9187817258883249
# Precision: 1.0
# Recall: 0.8367346938775511
# F1 Score: 0.9111111111111111

# %% [markdown]
# Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
print("Confusion Matrix (Naive Bayes):")
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Legit (0)", "Fraud (1)"])
disp.plot(cmap=plt.cm.Oranges)
plt.title("Naive Bayes - Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix (Naive Bayes):

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93        99
#            1       1.00      0.84      0.91        98
#
#     accuracy                           0.92       197
#    macro avg       0.93      0.92      0.92       197
# weighted avg       0.93      0.92      0.92       197
